# %%
# task 5 
import math
# 1)  Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.

# cреднее значение (математическое ожидание) u=(a+b)/2
# дисперсия sigma**2=(b-a)**2/12  
# станстандартное отклонение 
# равномерное распределение не имеет моды.

u = (200+800)/2
print(" 1 задача - среднее {u}")


#О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
#Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
#Если да, найдите ее.

# 0.2 = (b-0.5)**2/12
# (b-0.5)**2 = 2.4
# b - 0.5 = sqrt(2.4)
b = math.sqrt(2.4)+0.5
print(f" правая граница {b}")

#u=(a+b)/2
u = (2.09 + 0.5)/2
print(f" среднее {u}")
#


# Задача 3
#Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#f(x) = (1 / (4 * sqrt(2*pi))) * (exp(-((x+2)**2 / 32))).
#Найдите:
# 
#
# Ответ ищем по формуле в лекции
# Ответ:
#а). M(X) = -2
#б). D(X) = 4**2
#в). std(X) = 4 (среднее квадратичное отклонение)

#Рост взрослого населения города X имеет нормальное распределение.
#Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
#Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:

# воспользуемся правилами трех сигм

#а). больше 182 см

# 174-8 = 166 - нижняя граница для 1 сигм
# 174+ 8 = 182 - верхняя граница для 1 сигм

#  (100 - 68)/2 = 16%

# Ответ вероятность 16 % если 

#б). больше 190 см

# 174+2*8 = 190 = 2 сигм

# Ответ вероятность (100-95.4)/2 = 2.3%



#в). от 166 см до 190 см

# Ответ вероятность 68 + (95.4-68)/2)= 81.7 %


#г). от 166 см до 182 см

# Ответ вероятность 68 

#д). от 158 см до 190 см

# 174 - 8*2 = 158 

# Ответ вероятность 95.4 %

#е). не выше 150 см или не ниже 190 см

#  < 150 вероятность (100 - 99.72)/2 = 0.14
#  > 190 вероятность (100 - 95.4)/2 = 2.3

# Ответ вероятность 0.14 + 2.3

#ё). не выше 150 см или не ниже 198 см

# Ответ вероятность 100 - 99.72 = 0.28

#ж). ниже 166 см.

# Ответ вероятность (100/2 - 68/2) 


#На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
#математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# не очень понятная задача - но ответ такой напрашивается сигма = 5  (190 - 178)/5 = 12/5
# Out:
#  1 задача - среднее {u}
#  правая граница 2.049193338482967
#  среднее 1.295
